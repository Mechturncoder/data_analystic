# %%
import pandas as pd

# %%
# Importing the Dog-Bites dataset into a dataframe
dog_df = pd.read_csv("./data_pd/Dog_Bites_Data.csv")
dog_df.head()
# Out:
#    UniqueID       DateOfBite Species        Breed  Age Gender  SpayNeuter  \
# 0         1  January 01 2018     DOG      UNKNOWN  NaN      U       False
# 1         2  January 04 2018     DOG      UNKNOWN  NaN      U       False
# 2         3  January 06 2018     DOG     Pit Bull  NaN      U       False
# 3         4  January 08 2018     DOG  Mixed/Other    4      M       False
# 4         5  January 09 2018     DOG     Pit Bull  NaN      U       False
#
#     Borough ZipCode
# 0  Brooklyn   11220
# 1  Brooklyn     NaN
# 2  Brooklyn   11224
# 3  Brooklyn   11231
# 4  Brooklyn   11224

# %%
dog_df['DateOfBite'].dropna()
dog_df['Age'].dropna()
dog_df['Gender'].dropna()
dog_df['SpayNeuter'].dropna()
dog_df['ZipCode'].dropna()
len(dog_df)
# Out:
# 22663

# %%
filtered_dog_df = dog_df[dog_df['Gender'] != 'U']

# %%
filtered_dog_df.head(15)
# Out:
#     UniqueID       DateOfBite Species                                 Breed  \
# 3          4  January 08 2018     DOG                           Mixed/Other
# 5          6  January 03 2018     DOG                               BASENJI
# 8          9  January 04 2018     DOG  American Pit Bull Mix / Pit Bull Mix
# 9         10  January 10 2018     DOG                                 MIXED
# 11        12  January 07 2018     DOG          Yorkshire Terrier Crossbreed
# 12        13  January 06 2018     DOG                            Great Dane
# 14        15  January 09 2018     DOG                           Labradoodle
# 15        16  January 01 2018     DOG               West High White Terrier
# 18        19  January 13 2018     DOG                                 MIXED
# 20        21  January 15 2018     DOG                     Poodle, Miniature
# 21        22  January 13 2018     DOG    American Pit Bull Terrier/Pit Bull
# ...
