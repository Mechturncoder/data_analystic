# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
commuter_times = [16,8,35,17,13,15,15,5,16,25,20,20,12,10]
plt.figure(figsize=(10,8))
sns.boxplot(data=commuter_times, orient='h')
plt.title('Box plot of commuter times')
plt.xlabel('Minutes')
plt.show()

# %%
df = pd.read_csv('./data_pd/heart.csv')

# %%
cholestrol = df.chol

# %%
plt.figure(figsize=(10,8))
sns.boxplot(data=cholestrol, orient='h')
plt.title('Box plot of Cholestrol')
plt.xlabel('Chol')
plt.show()

# %%
# df.age.mean()   #54.366336633663366
n = df.age.count()  # 303
q1 = (25/100)*(n+1)
q3 = (75/100)*(n+1)
ls = df.sort_values(by='age', ascending=True)['age'].to_list()

Q1 = ls[int(q1) - 1]
Q3 = ls[int(q3) - 1]
# Q1 = np.percentile(ls, 25)
# Q3 = np.percentile(ls, 75)
IQR = Q3 - Q1
print(f"Q1 is {Q1}, Q3 is {Q3} and IQR is {IQR}")

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = [x for x in ls if x < lower_bound or x > upper_bound]

print("lower_bound: ", lower_bound)
print("upper_bound: ", upper_bound)
print("Arrays: ", ls)
print("Outliers: ", outliers)
# Out:
# Q1 is 47, Q3 is 61 and IQR is 14
# lower_bound:  26.0
# upper_bound:  82.0
# ...

# %%
df.sort_values(by='age', ascending=True)['age'].iloc[Q1]
# Out:
# 44
